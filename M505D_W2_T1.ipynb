# %% [markdown]
# <a href="https://colab.research.google.com/github/Umang-Gisma/M505D/blob/main/M505D_W2_T1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **M505D - Week 2** - Data collection and exploration

# %% [markdown]
# ### **Data Reading**

# %% [markdown]
# Import 'pandas' to access data from '.csv'

# %%
import pandas

# %% [markdown]
# Read and print the shap of data from '.csv'

# %%
df = pandas.read_csv("/content/bank_data_with_NaN.csv")
print("Shap of dataset: ", df.shape)
# Out:
# Shap of dataset:  (10000, 13)

# %% [markdown]
# Print the head of dataset with N numbers of rows

# %%
df.head(3)
# Out:
#            id last_name  credit_score      country gender   age  \
# 0  15634602.0  Hargrave         619.0  Switzerland      f  42.0
# 1  15647311.0      Hill         608.0      Austria      f  41.0
# 2  15619304.0      Onio         502.0  Switzerland      f  42.0
#
#    years_customer  balance_euros  num_products  has_credit_card  is_active  \
# 0             2.0           0.00           1.0              1.0        1.0
# 1             1.0       83807.86           1.0              0.0        1.0
# 2             8.0      159660.80           3.0              1.0        0.0
#
#    salary_euros  retained
# 0     101348.88       0.0
# 1     112542.58       1.0
# 2     113931.57       0.0

# %% [markdown]
# ###**Data Exploration**

# %% [markdown]
# Check empty or null data from dataset

# %%
df.isna().sum()
# Out:
# id                 102
# last_name           76
# credit_score        69
# country             80
# gender              73
# age                 79
# years_customer      85
# balance_euros       77
# num_products        64
# has_credit_card     73
# is_active           67
# salary_euros        75
# retained            75
# dtype: int64

# %% [markdown]
# Now explore the data

# %%
df["balance_euros"].hist(bins=5) #.hist shows the chart, and bins=5 is used for sepration of chart.
# Out:
# <Axes: >
